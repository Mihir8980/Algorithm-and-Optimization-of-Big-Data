# %% [markdown]
# # Q2. Multiple Linear Regression using Stocastic Gradient Descent
# (Generalization of Simple Linear Regression )

# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
from sklearn import preprocessing as pp
from sklearn import metrics
import matplotlib.pyplot as plt

# %% [markdown]
# Get Data

# %%
X, y = load_boston(return_X_y=True)
print(X.shape,y.shape)
# Out:
# (506, 13) (506,)

# %% [markdown]
# Stream Generator

# %%
def stream(X,y):
    for i in range(X.shape[0]):
        yield (X[i,:],y[i])

stream_train = stream(X_train,y_train)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 72

# %% [markdown]
# Data Pre-processing

# %%
#Splitting for training and testing
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2)
y_train = y_train.reshape((-1,1)) #reshape for (N,) --> (N,1)
y_test = y_test.reshape((-1,1))

#no normalization as data is not available all at once

print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (404, 13) (404, 1) (102, 13) (102, 1)

# %% [markdown]
# Parameter Learning using Stocastic Gradient Descent

# %%
#Intialization
theta = np.random.random(size=(X_train.shape[1]+1,1))
alpha = 0.000001 #learning_rate
M = X_train.shape[0]
err = []

#Gradient descent
while True :

    try:
        X,y = next(stream_train)
    except StopIteration :
        #if the training stream ends,stop training
        break

    X = pp.add_dummy_feature(X.reshape(1,-1))  #Adding dummy variable

    err.append(np.abs(error))
    theta = theta - (alpha)*(np.dot(X,theta) - y)*X.T  #updating theta for one sample

#final parameter values
print(theta.T)
print(theta.shape)
# Out:
# [[0.33737463 0.16315163 0.89899009 0.27712404 0.83268683 0.49386144
#   0.17433307 0.08202212 0.68029486 0.87963444 0.66942456 0.33462569
#   0.59446563 0.87096801]]
# (14, 1)

# %% [markdown]
# Testing

# %%
y_pred = np.dot(pp.add_dummy_feature(X_test),theta) #this cn be done with a stream as well but this happens sequentially anyway
print('MAE: ',metrics.mean_absolute_error(y_true=y_test,y_pred=y_pred))
print('MSE: ',metrics.mean_squared_error(y_true=y_test,y_pred=y_pred))
# Out:
# MAE:  507.91763943809394
# MSE:  270782.8601336898
